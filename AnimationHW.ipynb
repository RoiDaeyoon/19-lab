# %% [markdown]
# # Q. 아래 식을 애니메이션으로 그리시오.
#
# $$sin(2 \pi x) * exp(-0.1t)$$

# %% [markdown]
# #### numpy를 이용하여 sin, exp, pi 등을 표현하고 matplotlib로 애니메이션을 만든다.

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import sin, exp, pi
# %matplotlib inline

from matplotlib import animation, rc

# %% [markdown]
# #### 먼저 애니메이션을 만들 그래프 틀을 만들어 보자.

# %%
fig, ax = plt.subplots()

ax.set_xlim(( 0, 3))
ax.set_ylim((-1, 1)) # 표현하고자 하는 함수의 반복 단위

line, = ax.plot([], [], lw=2)

# %% [markdown]
# #### 이제 그래프 안에 들어갈 애니메이션을 지정해보자.

# %%
def init():
    line.set_data([], [])
    return (line,)

def animate(t):
    x = np.linspace(0, 10, 1000)
    y = sin(2 * pi * x) * exp(-0.1 * t)
    line.set_data(x, y)
    return (line,)

anim = animation.FuncAnimation(fig, animate, init_func=init, frames=90, interval=50, blit=True)

# %% [markdown]
# - fig : 현 그림의 객체
# - init_func : 초기화 함수로써 프레임이 리셋될 때 호출됨.
# - frames : 애니메이션의 초당 프레임 개수
# - interval : 프레임 간의 시간 간격 (밀리초 단위)
# - repeat : True, False 값을 가질 수 있으며 애니메이션의 반복 유무를 결정. (default는 True)

# %%
rc('animation', html='html5')

# %%
anim
# Out:
# <video width="432" height="288" controls autoplay loop>
#   <source type="video/mp4" src="...
